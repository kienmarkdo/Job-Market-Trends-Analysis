# %% [markdown]
# # Data Staging
# Extract, Transform, Load (ETL)

# %% [markdown]
# ## Extract datasets into dataframes

# %% [markdown]
# Extract job posting information

# %%
import pandas as pd
df = pd.read_csv('job_descriptions.csv')
df
# Out:
#                    Job Id     Experience Qualifications Salary Range  \
# 0        1089843540111562  5 to 15 Years         M.Tech    $59K-$99K
# 1         398454096642776  2 to 12 Years            BCA   $56K-$116K
# 2         481640072963533  0 to 12 Years            PhD   $61K-$104K
# 3         688192671473044  4 to 11 Years            PhD    $65K-$91K
# 4         117057806156508  1 to 12 Years            MBA    $64K-$87K
# ...                   ...            ...            ...          ...
# 1615935   134563577088850  0 to 12 Years         B.Tech   $64K-$114K
# 1615936   618604818190827  2 to 14 Years         M.Tech   $62K-$130K
# 1615937   615471367712200  4 to 15 Years            BCA    $60K-$96K
# 1615938   804137342023945  5 to 15 Years            BCA   $65K-$103K
# 1615939   404645755314484  1 to 11 Years            BBA   $56K-$109K
#
#                   location            Country  latitude  longitude  Work Type  \
# 0                  Douglas        Isle of Man   54.2361    -4.5481     Intern
# 1                 Ashgabat       Turkmenistan   38.9697    59.5563     Intern
# 2                    Macao   Macao SAR, China   22.1987   113.5439  Temporary
# 3               Porto-Novo              Benin    9.3077     2.3158  Full-Time
# 4                 Santiago              Chile  -35.6751   -71.5429     Intern
# ...                    ...                ...       ...        ...        ...
# 1615935  Malabo (de jure),  Equatorial Guinea    1.6508    10.2679  Full-Time
# 1615936             Warsaw             Poland   51.9194    19.1451     Intern
# 1615937           Ashgabat       Turkmenistan   38.9697    59.5563  Part-Time
# 1615938        Ouagadougou       Burkina Faso   12.2383    -1.5616  Full-Time
# 1615939             Asmara            Eritrea   15.1794    39.7823  Part-Time
#
#          Company Size  ...                Contact  \
# 0               26801  ...   001-381-930-7517x737
# 1              100340  ...           461-509-4216
# 2               84525  ...             9687619505
# 3              129896  ...  +1-820-643-5431x47576
# 4               53944  ...      343.975.4702x9340
# ...               ...  ...                    ...
# 1615935         18281  ...           950-451-5843
# 1615936         63621  ...     676.387.1572x71877
# 1615937        114287  ...      537.384.6193x5284
# 1615938         45009  ...     (484)257-4755x5346
# 1615939         87637  ...          (989)703-9723
#
#                             Job Title                        Role  \
# 0        Digital Marketing Specialist        Social Media Manager
# 1                       Web Developer      Frontend Web Developer
# 2                  Operations Manager     Quality Control Manager
# 3                    Network Engineer   Wireless Network Engineer
# 4                       Event Manager          Conference Manager
# ...                               ...                         ...
# 1615935           Mechanical Engineer  Mechanical Design Engineer
# 1615936                    IT Manager                 IT Director
# 1615937           Mechanical Engineer  Mechanical Design Engineer
# 1615938                HR Coordinator        Training Coordinator
# 1615939                 Event Planner             Wedding Planner
#
#                   Job Portal  \
# 0                   Snagajob
# 1                   Idealist
# 2               Jobs2Careers
# 3                   FlexJobs
# 4               Jobs2Careers
# ...                      ...
# 1615935         ZipRecruiter
# 1615936              USAJOBS
# 1615937               Indeed
# 1615938  Stack Overflow Jobs
# 1615939              USAJOBS
#
#                                            Job Description  \
# 0        Social Media Managers oversee an organizations...
# 1        Frontend Web Developers design and implement u...
# 2        Quality Control Managers establish and enforce...
# 3        Wireless Network Engineers design, implement, ...
# 4        A Conference Manager coordinates and manages c...
# ...                                                    ...
# 1615935  Mechanical Design Engineers create and develop...
# 1615936  An IT Director oversees an organizations IT de...
# 1615937  Mechanical Design Engineers create and develop...
# 1615938  Training Coordinators design and implement emp...
# 1615939  Wedding Planners specialize in organizing wedd...
#
#                                                   Benefits  \
# 0        {'Flexible Spending Accounts (FSAs), Relocatio...
# 1        {'Health Insurance, Retirement Plans, Paid Tim...
# 2        {'Legal Assistance, Bonuses and Incentive Prog...
# 3        {'Transportation Benefits, Professional Develo...
# 4        {'Flexible Spending Accounts (FSAs), Relocatio...
# ...                                                    ...
# 1615935  {'Employee Assistance Programs (EAP), Tuition ...
# 1615936  {'Health Insurance, Retirement Plans, Paid Tim...
# 1615937  {'Tuition Reimbursement, Stock Options or Equi...
# 1615938  {'Casual Dress Code, Social and Recreational A...
# 1615939  {'Transportation Benefits, Professional Develo...
#
#                                                     skills  \
# 0        Social media platforms (e.g., Facebook, Twitte...
# 1        HTML, CSS, JavaScript Frontend frameworks (e.g...
# 2        Quality control processes and methodologies St...
# 3        Wireless network design and architecture Wi-Fi...
# 4        Event planning Conference logistics Budget man...
# ...                                                    ...
# 1615935  Mechanical engineering CAD software (e.g., Sol...
# 1615936  Strategic IT planning Leadership and managemen...
# 1615937  Mechanical engineering CAD software (e.g., Sol...
# 1615938  Training program coordination Training materia...
# 1615939  Wedding planning Venue selection Catering and ...
#
#                                           Responsibilities  \
# 0        Manage and grow social media accounts, create ...
# 1        Design and code user interfaces for websites, ...
# 2        Establish and enforce quality control standard...
# 3        Design, configure, and optimize wireless netwo...
# 4        Specialize in conference and convention planni...
# ...                                                    ...
# 1615935  Design mechanical systems, components, and pro...
# 1615936  Provide strategic leadership for IT department...
# 1615937  Design mechanical systems, components, and pro...
# 1615938  Coordinate employee training programs, track t...
# 1615939  Specialize in wedding planning, assisting coup...
#
#                                   Company  \
# 0                       Icahn Enterprises
# 1            PNC Financial Services Group
# 2        United Services Automobile Assn.
# 3                                    Hess
# 4                            Cairn Energy
# ...                                   ...
# 1615935               The Hershey Company
# 1615936                               EQT
# 1615937                               KLA
# 1615938               Mahindra & Mahindra
# 1615939                     Ashtead Group
#
#                                            Company Profile
# 0        {"Sector":"Diversified","Industry":"Diversifie...
# 1        {"Sector":"Financial Services","Industry":"Com...
# 2        {"Sector":"Insurance","Industry":"Insurance: P...
# 3        {"Sector":"Energy","Industry":"Mining, Crude-O...
# 4        {"Sector":"Energy","Industry":"Energy - Oil & ...
# ...                                                    ...
# 1615935  {"Sector":"Food and Beverage/Confectionery","I...
# 1615936  {"Sector":"Energy","Industry":"Energy","City":...
# 1615937  {"Sector":"Technology","Industry":"Semiconduct...
# 1615938  {"Sector":"Automotive","Industry":"Automotive"...
# 1615939  {"Sector":"Equipment Rental","Industry":"Equip...
#
# [1615940 rows x 23 columns]

# %% [markdown]
# Extract City Population information

# %%
df_population = pd.read_csv('CityPopulation.csv')
df_population
# Out:
#       Country                City City Population
# 0         USA    Washington, D.C.         678,972
# 1          UK              London       9,748,000
# 2      Canada              Ottawa       1,077,900
# 3      France               Paris      11,208,000
# 4     Belgium            Brussels       1,222,657
# 5   Australia            Canberra         472,000
# 6       Spain              Madrid       6,751,000
# 7       India           New Delhi      32,941,000
# 8     Germany              Berlin       3,574,000
# 9   Singapore           Singapore       6,014,723
# 10   Thailand             Bangkok      11,070,000
# 11      China             Beijing      21,766,000
# 12   Portugal              Lisbon       3,001,000
# 13    Vietnam               Hanoi       8,587,141
# 14  Mauritius  City of Port Louis         145,203
# 15      Japan               Tokyo      37,115,035

# %% [markdown]
# Extract company headquarters country location

# %%
df_hq_country = pd.read_csv('CompanyHQLocation.csv')
df_hq_country
# Out:
#                                    Company  Country
# 0    Adani Ports and Special Economic Zone    India
# 1                               CBRE Group      USA
# 2                                  Arconic      USA
# 3                          GlaxoSmithKline       UK
# 4                       Equitable Holdings      USA
# ..                                     ...      ...
# 884                                  Avnet      USA
# 885                  Western Union Company      USA
# 886                                BASF SE  Germany
# 887            Reliance Industries Limited    India
# 888                  United Breweries (UB)    India
#
# [889 rows x 2 columns]

# %% [markdown]
# ## Transform

# %%
pd.options.mode.copy_on_write = True #https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
print(df.dtypes)
# Out:
# Job Id                int64
# Experience           object
# Qualifications       object
# Salary Range         object
# location             object
# Country              object
# latitude            float64
# longitude           float64
# Work Type            object
# Company Size          int64
# Job Posting Date     object
# Preference           object
# Contact Person       object
# Contact              object
# Job Title            object
# Role                 object
# Job Portal           object
# Job Description      object
# Benefits             object
# skills               object
# Responsibilities     object
# Company              object
# Company Profile      object
# dtype: object

# %% [markdown]
# Keep only the countries we want for our analysis

# %%
# Define the values to keep in the "Country" column
desired_countries = ['USA', 'UK', 'Canada', 'France', 'Japan', 'Belgium', 'Australia', 'Spain', 'India', 'Germany', 'Singapore', 'Thailand', 'China', 'Portugal', 'Vietnam', 'Mauritius']

# Filter the DataFrame to keep only rows with desired countries
df = df[df['Country'].isin(desired_countries)]

# %% [markdown]
# Drop unrequired columns

# %%
df = df.drop(columns = ['latitude', 'longitude', 'Contact Person', 'Contact', 'Job Description'])
df
# Out:
#                    Job Id     Experience Qualifications Salary Range  \
# 5         116831420231957  4 to 12 Years            MCA    $59K-$93K
# 34       1889088294438825   0 to 8 Years          M.Com   $62K-$130K
# 46       1373513885523551   3 to 9 Years         B.Tech   $56K-$109K
# 61        401560922349533  5 to 12 Years            PhD   $57K-$125K
# 69       2853459439973158   0 to 9 Years         B.Tech   $56K-$125K
# ...                   ...            ...            ...          ...
# 1615879   934065317714728  0 to 15 Years          B.Com   $64K-$113K
# 1615885  2072349359037720  2 to 13 Years            PhD   $65K-$126K
# 1615911  2800492340115484   4 to 9 Years            MBA    $60K-$87K
# 1615930   690948368250854  1 to 14 Years            BCA   $65K-$125K
# 1615934   371430155110052  3 to 13 Years            MBA   $58K-$126K
#
#           location    Country  Work Type  Company Size Job Posting Date  \
# 5         Brussels    Belgium  Full-Time         23196       2023-07-25
# 34        Canberra  Australia  Temporary         27725       2022-11-02
# 46          Madrid      Spain  Temporary         91636       2023-05-29
# 61       New Delhi      India  Full-Time         42159       2022-09-28
# 69          London         UK     Intern         58034       2022-08-03
# ...            ...        ...        ...           ...              ...
# 1615879     London         UK   Contract         43471       2023-04-18
# 1615885    Bangkok   Thailand  Temporary         95005       2022-04-14
# 1615911     London         UK   Contract         29238       2022-02-18
# 1615930     Madrid      Spain     Intern        131847       2022-07-10
# 1615934  New Delhi      India  Full-Time        123392       2023-04-11
#
#         Preference                 Job Title                       Role  \
# 5             Male           Software Tester  Quality Assurance Analyst
# 34            Both       Electrical Designer          Lighting Designer
# 46            Male          Data Entry Clerk              Record Keeper
# 61          Female         Account Executive    Sales Account Executive
# 69            Male             Data Engineer             Data Architect
# ...            ...                       ...                        ...
# 1615879       Male             Brand Manager      Product Brand Manager
# 1615885       Male         Event Coordinator              Event Planner
# 1615911       Both          Sales Consultant              Sales Advisor
# 1615930       Both  Environmental Consultant  Sustainability Consultant
# 1615934     Female             Social Worker       Child Welfare Worker
#
#               Job Portal                                           Benefits  \
# 5               Snagajob  {'Life and Disability Insurance, Stock Options...
# 34              Idealist  {'Life and Disability Insurance, Stock Options...
# 46          Jobs2Careers  {'Legal Assistance, Bonuses and Incentive Prog...
# 61       Internships.com  {'Flexible Spending Accounts (FSAs), Relocatio...
# 69                Indeed  {'Childcare Assistance, Paid Time Off (PTO), R...
# ...                  ...                                                ...
# 1615879          USAJOBS  {'Legal Assistance, Bonuses and Incentive Prog...
# 1615885         Idealist  {'Legal Assistance, Bonuses and Incentive Prog...
# 1615911         Snagajob  {'Childcare Assistance, Paid Time Off (PTO), R...
# 1615930  Internships.com  {'Employee Assistance Programs (EAP), Tuition ...
# 1615934      SimplyHired  {'Transportation Benefits, Professional Develo...
#
#                                                     skills  \
# 5        Quality assurance processes Testing methodolog...
# 34       Lighting design Architectural lighting Lightin...
# 46       Records management Data entry and retrieval At...
# 61       Sales strategies and tactics Account managemen...
# 69       Data architecture design Database management s...
# ...                                                    ...
# 1615879  Product branding and marketing Product lifecyc...
# 1615885  Event planning and coordination Budget managem...
# 1615911  Sales strategies Customer relationship managem...
# 1615930  Sustainability consulting Sustainability asses...
# 1615934  Child welfare policies and regulations Child p...
#
#                                           Responsibilities  \
# 5        Test software applications and systems to iden...
# 34       Specialize in lighting design, creating lighti...
# 46       Maintain records, files, and documentation in ...
# 61       Identify and pursue sales opportunities with n...
# 69       Design data architecture and systems to meet b...
# ...                                                    ...
# 1615879  Manage the branding of specific products or pr...
# 1615885  Plan and organize events, such as weddings, co...
# 1615911  Provide expert advice and guidance to customer...
# 1615930  Focus on sustainable practices and initiatives...
# 1615934  Provide support and counseling to children and...
#
#                                        Company  \
# 5        Adani Ports and Special Economic Zone
# 34                                  CBRE Group
# 46                                     Arconic
# 61                             GlaxoSmithKline
# 69                          Equitable Holdings
# ...                                        ...
# 1615879                          Kinder Morgan
# 1615885                      Chesapeake Energy
# 1615911                             Unum Group
# 1615930                           J.M. Smucker
# 1615934                      Icahn Enterprises
#
#                                            Company Profile
# 5        {"Sector":"Infrastructure","Industry":"Ports a...
# 34       {"Sector":"Real Estate","Industry":"Real Estat...
# 46       {"Sector":"Manufacturing","Industry":"Metals",...
# 61       {"Sector":"Pharmaceuticals","Industry":"Pharma...
# 69       {"Sector":"Insurance","Industry":"Insurance: L...
# ...                                                    ...
# 1615879  {"Sector":"Energy","Industry":"Pipelines","Cit...
# 1615885  {"Sector":"Energy","Industry":"Mining, Crude-O...
# 1615911  {"Sector":"Insurance","Industry":"Insurance: L...
# 1615930  {"Sector":"Food & Beverage","Industry":"Food C...
# 1615934  {"Sector":"Diversified","Industry":"Diversifie...
#
# [119526 rows x 18 columns]

# %% [markdown]
# Renaming columns

# %%
# Columns to rename in df
columns_to_rename = {
    'skills':'Skills',
    'location': 'City',
    'Preference': 'Gender Preference',
    'Role': 'Specialization',
}

df = df.rename(columns_to_rename, axis='columns')

# columns to rename in df_population
df_population.rename(columns={'City Population': 'Job City Population'}, inplace=True)

# column to rename in df_hq_country
df_hq_country.rename(columns={'Country': 'Company HQ Country'}, inplace=True)

# %% [markdown]
# Processing date values

# %%
# convert date object to datetime
df['Job Posting Date'] = pd.to_datetime(df['Job Posting Date'])
df.dtypes
# Out:
# Job Id                        int64
# Experience                   object
# Qualifications               object
# Salary Range                 object
# City                         object
# Country                      object
# Work Type                    object
# Company Size                  int64
# Job Posting Date     datetime64[ns]
# Gender Preference            object
# Job Title                    object
# Specialization               object
# Job Portal                   object
# Benefits                     object
# Skills                       object
# Responsibilities             object
# Company                      object
# Company Profile              object
# dtype: object

# %%
# Extract the month and year from job posting date and add them to 2 separate columns
df['Day'] = df['Job Posting Date'].dt.day # extract day
df['Month'] = df['Job Posting Date'].dt.month # extract month
df['Year'] = df['Job Posting Date'].dt.year # extract year

# %% [markdown]
# Processing Salary Range and Years of Experience

# %%
# Split salary range in to minimum salary and maximum salary
df[['Minimum Salary', 'Maximum Salary']] = df['Salary Range'].str.split('-', expand=True)

# Keep only integers, using a regex, replace every non digit character by a ""
df['Minimum Salary'] = df['Minimum Salary'].str.replace('[^\d]', '', regex=True).astype(int)
df['Maximum Salary'] = df['Maximum Salary'].str.replace('[^\d]', '', regex=True).astype(int)

# %%
# Transform salary into $ instead of in thousands unit
df['Minimum Salary'] *= 1000
df['Maximum Salary'] *= 1000

# %%
# Split Years of experience range in to minimum experience and maximum experience
df[['Minimum Experience (years)', 'Maximum Experience (years)']] = df['Experience'].str.split('to', expand=True)

# Keep only integers, using a regex, replace every non digit character by a ""
df['Minimum Experience (years)'] = df['Minimum Experience (years)'].str.replace('[^\d]', '', regex=True).astype(int)
df['Maximum Experience (years)'] = df['Maximum Experience (years)'].str.replace('[^\d]', '', regex=True).astype(int)

# %%
# Drop unneeded columns
df = df.drop(columns=['Experience', 'Salary Range', 'Job Posting Date'])
df
# Out:
#                    Job Id Qualifications       City    Country  Work Type  \
# 5         116831420231957            MCA   Brussels    Belgium  Full-Time
# 34       1889088294438825          M.Com   Canberra  Australia  Temporary
# 46       1373513885523551         B.Tech     Madrid      Spain  Temporary
# 61        401560922349533            PhD  New Delhi      India  Full-Time
# 69       2853459439973158         B.Tech     London         UK     Intern
# ...                   ...            ...        ...        ...        ...
# 1615879   934065317714728          B.Com     London         UK   Contract
# 1615885  2072349359037720            PhD    Bangkok   Thailand  Temporary
# 1615911  2800492340115484            MBA     London         UK   Contract
# 1615930   690948368250854            BCA     Madrid      Spain     Intern
# 1615934   371430155110052            MBA  New Delhi      India  Full-Time
#
#          Company Size Gender Preference                 Job Title  \
# 5               23196              Male           Software Tester
# 34              27725              Both       Electrical Designer
# 46              91636              Male          Data Entry Clerk
# 61              42159            Female         Account Executive
# 69              58034              Male             Data Engineer
# ...               ...               ...                       ...
# 1615879         43471              Male             Brand Manager
# 1615885         95005              Male         Event Coordinator
# 1615911         29238              Both          Sales Consultant
# 1615930        131847              Both  Environmental Consultant
# 1615934        123392            Female             Social Worker
#
#                     Specialization       Job Portal  ...  \
# 5        Quality Assurance Analyst         Snagajob  ...
# 34               Lighting Designer         Idealist  ...
# 46                   Record Keeper     Jobs2Careers  ...
# 61         Sales Account Executive  Internships.com  ...
# 69                  Data Architect           Indeed  ...
# ...                            ...              ...  ...
# 1615879      Product Brand Manager          USAJOBS  ...
# 1615885              Event Planner         Idealist  ...
# 1615911              Sales Advisor         Snagajob  ...
# 1615930  Sustainability Consultant  Internships.com  ...
# 1615934       Child Welfare Worker      SimplyHired  ...
#
#                                           Responsibilities  \
# 5        Test software applications and systems to iden...
# 34       Specialize in lighting design, creating lighti...
# 46       Maintain records, files, and documentation in ...
# 61       Identify and pursue sales opportunities with n...
# 69       Design data architecture and systems to meet b...
# ...                                                    ...
# 1615879  Manage the branding of specific products or pr...
# 1615885  Plan and organize events, such as weddings, co...
# 1615911  Provide expert advice and guidance to customer...
# 1615930  Focus on sustainable practices and initiatives...
# 1615934  Provide support and counseling to children and...
#
#                                        Company  \
# 5        Adani Ports and Special Economic Zone
# 34                                  CBRE Group
# 46                                     Arconic
# 61                             GlaxoSmithKline
# 69                          Equitable Holdings
# ...                                        ...
# 1615879                          Kinder Morgan
# 1615885                      Chesapeake Energy
# 1615911                             Unum Group
# 1615930                           J.M. Smucker
# 1615934                      Icahn Enterprises
#
#                                            Company Profile Day Month  Year  \
# 5        {"Sector":"Infrastructure","Industry":"Ports a...  25     7  2023
# 34       {"Sector":"Real Estate","Industry":"Real Estat...   2    11  2022
# 46       {"Sector":"Manufacturing","Industry":"Metals",...  29     5  2023
# 61       {"Sector":"Pharmaceuticals","Industry":"Pharma...  28     9  2022
# 69       {"Sector":"Insurance","Industry":"Insurance: L...   3     8  2022
# ...                                                    ...  ..   ...   ...
# 1615879  {"Sector":"Energy","Industry":"Pipelines","Cit...  18     4  2023
# 1615885  {"Sector":"Energy","Industry":"Mining, Crude-O...  14     4  2022
# 1615911  {"Sector":"Insurance","Industry":"Insurance: L...  18     2  2022
# 1615930  {"Sector":"Food & Beverage","Industry":"Food C...  10     7  2022
# 1615934  {"Sector":"Diversified","Industry":"Diversifie...  11     4  2023
#
#          Minimum Salary  Maximum Salary  Minimum Experience (years)  \
# 5                 59000           93000                           4
# 34                62000          130000                           0
# 46                56000          109000                           3
# 61                57000          125000                           5
# 69                56000          125000                           0
# ...                 ...             ...                         ...
# 1615879           64000          113000                           0
# 1615885           65000          126000                           2
# 1615911           60000           87000                           4
# 1615930           65000          125000                           1
# 1615934           58000          126000                           3
#
#          Maximum Experience (years)
# 5                                12
# 34                                8
# 46                                9
# 61                               12
# 69                                9
# ...                             ...
# 1615879                          15
# 1615885                          13
# 1615911                           9
# 1615930                          14
# 1615934                          13
#
# [119526 rows x 22 columns]

# %% [markdown]
# Handling null values within company profile

# %%
# Check if there are null values, no null values if we successfully added missing companies
df.isnull().sum()
# Out:
# Job Id                          0
# Qualifications                  0
# City                            0
# Country                         0
# Work Type                       0
# Company Size                    0
# Gender Preference               0
# Job Title                       0
# Specialization                  0
# Job Portal                      0
# Benefits                        0
# Skills                          0
# Responsibilities                0
# Company                         0
# Company Profile               407
# Day                             0
# Month                           0
# Year                            0
# Minimum Salary                  0
# Maximum Salary                  0
# Minimum Experience (years)      0
# Maximum Experience (years)      0
# dtype: int64

# %%
# Checking which company has missing information on company profile
null_company_profile_rows = df[df['Company Profile'].isnull() | (df['Company Profile'] == '')]

# Extract unique companies from these rows
unique_companies_with_null_profile = null_company_profile_rows['Company'].unique()

print(unique_companies_with_null_profile)
# Out:
# ['Estée Lauder' "Dunkin'Brands Group, Inc." 'Peter Kiewit Sons']

# %%
# handling missing values for company profile
import json
value_mapping = {
    'Estée Lauder': {"Sector":"Consumer Goods","Industry":"Consumer Goods","City":"New York","State":"New York","Zip":"10001","Website":"www.elcompanies.com","Ticker":"EL","CEO":"Fabrizio Freda"},
    'Dunkin\'Brands Group, Inc.': {"Sector":"Restaurants","Industry":"Food Services","City":"Canton","State":"Massachusetts","Zip":"02021","Website":"www.dunkindonuts.com","Ticker":"DNKN","CEO":"Nigel Travis"},
    'Peter Kiewit Sons': {"Sector":"Construction/Infrastructure","Industry":"Construction/Infrastructure","City":"Ottawa","State":"Ontario","Zip":"K1H 1E1","Website":"www.kiewit.com","Ticker":"N/A","CEO":"Rick Lanoha"},
}

# Filling in missing information for company profile
for index, row in df.iterrows():
    if pd.isnull(row['Company Profile']):
        company = row['Company']
        if company in value_mapping:
          company_profile_str = json.dumps(value_mapping[company])
          df.at[index, 'Company Profile'] = company_profile_str

# %%
# Checking if missing data was filled in properly

df.isnull().sum()
# Out:
# Job Id                        0
# Qualifications                0
# City                          0
# Country                       0
# Work Type                     0
# Company Size                  0
# Gender Preference             0
# Job Title                     0
# Specialization                0
# Job Portal                    0
# Benefits                      0
# Skills                        0
# Responsibilities              0
# Company                       0
# Company Profile               0
# Day                           0
# Month                         0
# Year                          0
# Minimum Salary                0
# Maximum Salary                0
# Minimum Experience (years)    0
# Maximum Experience (years)    0
# dtype: int64

# %% [markdown]
# Cleaning data for Company Profile

# %%
# Cleaning data that is formatted incorrectly in Company Profile
rows_to_replace = df[df['Company'] == 'Quanta Services']
df.loc[rows_to_replace.index, 'Company Profile'] = df.loc[rows_to_replace.index, 'Company Profile'].str.replace('"Duke" Austin', 'Austin')

# %% [markdown]
# Processing the Company Profile column
#
# Format for Company Profile is a dictionnary, and we want to have a column for each key of the dictionnary and fill the column with the value associated to the key

# %%
import ast

def extract_and_rename(dictionary_str, key, new_key):
    try:
        dictionary = ast.literal_eval(dictionary_str)
        value = dictionary.get(key, None)
        return value if value is not None else None
    except (SyntaxError, ValueError):
        return None

# Define keys to extract and their column names
key_to_new_key_mapping = {
    'Sector': 'Company Sector',
    'Industry': 'Company Industry',
    'City': 'Company HQ City',
    'Ticker': 'Company Ticker'
}

# Create new columns and fill with values
for key, new_key in key_to_new_key_mapping.items():
    df[new_key] = df['Company Profile'].apply(lambda x: extract_and_rename(x, key, new_key))

# Drop the original Company Profile column
df.drop(columns=['Company Profile'], inplace=True)
df
# Out:
#                    Job Id Qualifications       City    Country  Work Type  \
# 5         116831420231957            MCA   Brussels    Belgium  Full-Time
# 34       1889088294438825          M.Com   Canberra  Australia  Temporary
# 46       1373513885523551         B.Tech     Madrid      Spain  Temporary
# 61        401560922349533            PhD  New Delhi      India  Full-Time
# 69       2853459439973158         B.Tech     London         UK     Intern
# ...                   ...            ...        ...        ...        ...
# 1615879   934065317714728          B.Com     London         UK   Contract
# 1615885  2072349359037720            PhD    Bangkok   Thailand  Temporary
# 1615911  2800492340115484            MBA     London         UK   Contract
# 1615930   690948368250854            BCA     Madrid      Spain     Intern
# 1615934   371430155110052            MBA  New Delhi      India  Full-Time
#
#          Company Size Gender Preference                 Job Title  \
# 5               23196              Male           Software Tester
# 34              27725              Both       Electrical Designer
# 46              91636              Male          Data Entry Clerk
# 61              42159            Female         Account Executive
# 69              58034              Male             Data Engineer
# ...               ...               ...                       ...
# 1615879         43471              Male             Brand Manager
# 1615885         95005              Male         Event Coordinator
# 1615911         29238              Both          Sales Consultant
# 1615930        131847              Both  Environmental Consultant
# 1615934        123392            Female             Social Worker
#
#                     Specialization       Job Portal  ... Month  Year  \
# 5        Quality Assurance Analyst         Snagajob  ...     7  2023
# 34               Lighting Designer         Idealist  ...    11  2022
# 46                   Record Keeper     Jobs2Careers  ...     5  2023
# 61         Sales Account Executive  Internships.com  ...     9  2022
# 69                  Data Architect           Indeed  ...     8  2022
# ...                            ...              ...  ...   ...   ...
# 1615879      Product Brand Manager          USAJOBS  ...     4  2023
# 1615885              Event Planner         Idealist  ...     4  2022
# 1615911              Sales Advisor         Snagajob  ...     2  2022
# 1615930  Sustainability Consultant  Internships.com  ...     7  2022
# 1615934       Child Welfare Worker      SimplyHired  ...     4  2023
#
#         Minimum Salary Maximum Salary  Minimum Experience (years)  \
# 5                59000          93000                           4
# 34               62000         130000                           0
# 46               56000         109000                           3
# 61               57000         125000                           5
# 69               56000         125000                           0
# ...                ...            ...                         ...
# 1615879          64000         113000                           0
# 1615885          65000         126000                           2
# 1615911          60000          87000                           4
# 1615930          65000         125000                           1
# 1615934          58000         126000                           3
#
#          Maximum Experience (years)   Company Sector  \
# 5                                12   Infrastructure
# 34                                8      Real Estate
# 46                                9    Manufacturing
# 61                               12  Pharmaceuticals
# 69                                9        Insurance
# ...                             ...              ...
# 1615879                          15           Energy
# 1615885                          13           Energy
# 1615911                           9        Insurance
# 1615930                          14  Food & Beverage
# 1615934                          13      Diversified
#
#                         Company Industry    Company HQ City  Company Ticker
# 5               Ports and Infrastructure             Mundra      ADANIPORTS
# 34                           Real Estate             Dallas            CBRE
# 46                                Metals         Pittsburgh            ARNC
# 61                       Pharmaceuticals             London             GSK
# 69       Insurance: Life, Health (Stock)           New York             EQH
# ...                                  ...                ...             ...
# 1615879                        Pipelines            Houston             KMI
# 1615885     Mining, Crude-Oil Production      Oklahoma City             CHK
# 1615911  Insurance: Life, Health (Stock)        Chattanooga             UNM
# 1615930           Food Consumer Products           Orrville             SJM
# 1615934           Diversified Financials  Sunny Isles Beach             IEP
#
# [119526 rows x 25 columns]

# %% [markdown]
# Cleaning the Company HQ City column
#
# We noticed that some values for the City key included the city inside of it, so for example we have "City": "London, UK", but we only want the London part in that column

# %%
# We split at the comma
split_cities = df['Company HQ City'].str.split(',')

# Filtering elements with length 2
split_cities_with_length_2 = split_cities[split_cities.apply(lambda x: len(x) == 2)]

# Getting indices of rows with split cities of length 2
indices_with_length_2 = split_cities_with_length_2.index

# Replacing the existing values with only the first element of the split list
df.loc[indices_with_length_2, 'Company HQ City'] = split_cities_with_length_2.apply(lambda x: x[0])

# %%
# Checking if there are still rows with the format where we have the country, if the output returns nothing, then we cleaned properly

# Splitting the content of the 'Company HQ City' column at the comma
split_cities = df['Company HQ City'].str.split(',')

# Filtering elements with length 2
split_cities_with_length_2 = split_cities[split_cities.apply(lambda x: len(x) == 2)]

# Displaying the split content with elements of length 2
print(split_cities_with_length_2)
# Out:
# Series([], Name: Company HQ City, dtype: object)

# %% [markdown]
# Processing the Benefits values
#
# Format of Benefits table is {'Retirement Plans', 'Parental Leave', etc} and we want to have a column for each benefit and if the benefit is in the Object, we have True, and if it's not there we have False. So with the Object given above, Retirement Plans and Parental Leave will have True in their column and the others will have False

# %%
benefit_columns = ['Retirement Plans','Stock Options or Equity Grants','Parental Leave','Paid Time Off (PTO)',
                   'Flexible Work Arrangements','Health Insurance','Life and Disability Insurance',
                   'Employee Assistance Program','Health and Wellness Facilities','Employee Referral Program',
                   'Transportation Benefits','Bonuses and Incentive Programs']

# Initialize all columns with False
for column in benefit_columns:
    df[column] = False

# Function to set boolean values
def set_benefit_values(row):
    benefits = row['Benefits']
    for column in benefit_columns:
        if column in benefits:
            row[column] = True
    return row

# Apply function to each row
df = df.apply(set_benefit_values, axis=1)

# Drop the original Benefits column
df.drop(columns=['Benefits'], inplace=True)
df
# Out:
#                    Job Id Qualifications       City    Country  Work Type  \
# 5         116831420231957            MCA   Brussels    Belgium  Full-Time
# 34       1889088294438825          M.Com   Canberra  Australia  Temporary
# 46       1373513885523551         B.Tech     Madrid      Spain  Temporary
# 61        401560922349533            PhD  New Delhi      India  Full-Time
# 69       2853459439973158         B.Tech     London         UK     Intern
# ...                   ...            ...        ...        ...        ...
# 1615879   934065317714728          B.Com     London         UK   Contract
# 1615885  2072349359037720            PhD    Bangkok   Thailand  Temporary
# 1615911  2800492340115484            MBA     London         UK   Contract
# 1615930   690948368250854            BCA     Madrid      Spain     Intern
# 1615934   371430155110052            MBA  New Delhi      India  Full-Time
#
#          Company Size Gender Preference                 Job Title  \
# 5               23196              Male           Software Tester
# 34              27725              Both       Electrical Designer
# 46              91636              Male          Data Entry Clerk
# 61              42159            Female         Account Executive
# 69              58034              Male             Data Engineer
# ...               ...               ...                       ...
# 1615879         43471              Male             Brand Manager
# 1615885         95005              Male         Event Coordinator
# 1615911         29238              Both          Sales Consultant
# 1615930        131847              Both  Environmental Consultant
# 1615934        123392            Female             Social Worker
#
#                     Specialization       Job Portal  ... Parental Leave  \
# 5        Quality Assurance Analyst         Snagajob  ...          False
# 34               Lighting Designer         Idealist  ...          False
# 46                   Record Keeper     Jobs2Careers  ...          False
# 61         Sales Account Executive  Internships.com  ...          False
# 69                  Data Architect           Indeed  ...          False
# ...                            ...              ...  ...            ...
# 1615879      Product Brand Manager          USAJOBS  ...          False
# 1615885              Event Planner         Idealist  ...          False
# 1615911              Sales Advisor         Snagajob  ...          False
# 1615930  Sustainability Consultant  Internships.com  ...           True
# 1615934       Child Welfare Worker      SimplyHired  ...          False
#
#         Paid Time Off (PTO) Flexible Work Arrangements  Health Insurance  \
# 5                     False                      False              True
# 34                    False                      False              True
# 46                    False                      False             False
# 61                    False                      False             False
# 69                     True                       True             False
# ...                     ...                        ...               ...
# 1615879               False                      False             False
# 1615885               False                      False             False
# 1615911                True                       True             False
# 1615930               False                      False             False
# 1615934               False                      False             False
#
#          Life and Disability Insurance  Employee Assistance Program  \
# 5                                 True                        False
# 34                                True                        False
# 46                               False                        False
# 61                               False                        False
# 69                               False                        False
# ...                                ...                          ...
# 1615879                          False                        False
# 1615885                          False                        False
# 1615911                          False                        False
# 1615930                          False                         True
# 1615934                          False                        False
#
#          Health and Wellness Facilities  Employee Referral Program  \
# 5                                 False                      False
# 34                                False                      False
# 46                                False                      False
# 61                                False                      False
# 69                                False                      False
# ...                                 ...                        ...
# 1615879                           False                      False
# 1615885                           False                      False
# 1615911                           False                      False
# 1615930                           False                      False
# 1615934                           False                      False
#
#          Transportation Benefits  Bonuses and Incentive Programs
# 5                          False                           False
# 34                         False                           False
# 46                         False                            True
# 61                         False                           False
# 69                         False                           False
# ...                          ...                             ...
# 1615879                    False                            True
# 1615885                    False                            True
# 1615911                    False                           False
# 1615930                     True                           False
# 1615934                     True                            True
#
# [119526 rows x 36 columns]

# %%
# Checking if we have null values
df.isnull().sum()
# Out:
# Job Id                            0
# Qualifications                    0
# City                              0
# Country                           0
# Work Type                         0
# Company Size                      0
# Gender Preference                 0
# Job Title                         0
# Specialization                    0
# Job Portal                        0
# Skills                            0
# Responsibilities                  0
# Company                           0
# Day                               0
# Month                             0
# Year                              0
# Minimum Salary                    0
# Maximum Salary                    0
# Minimum Experience (years)        0
# Maximum Experience (years)        0
# Company Sector                    0
# Company Industry                  0
# Company HQ City                   0
# Company Ticker                    0
# Retirement Plans                  0
# Stock Options or Equity Grants    0
# Parental Leave                    0
# Paid Time Off (PTO)               0
# Flexible Work Arrangements        0
# Health Insurance                  0
# Life and Disability Insurance     0
# Employee Assistance Program       0
# Health and Wellness Facilities    0
# Employee Referral Program         0
# Transportation Benefits           0
# Bonuses and Incentive Programs    0
# dtype: int64

# %% [markdown]
# ### Dataset Integrations

# %% [markdown]
# We integrate our 3 datasets together: job_descriptions.csv, CityPopulation.csv and CompanyHQLocation.csv

# %%
df = pd.merge(df, df_population, how='left', on=["City", "Country"])
df = pd.merge(df, df_hq_country, how='left', on=["Company"])

# %%
# Remove comma from population
df['Job City Population'] = df['Job City Population'].str.replace(',', '')

# Convert the City population to integer format
df['Job City Population'] = df['Job City Population'].astype('int64')

df.head(5)
# Out:
#              Job Id Qualifications       City    Country  Work Type  \
# 0   116831420231957            MCA   Brussels    Belgium  Full-Time
# 1  1889088294438825          M.Com   Canberra  Australia  Temporary
# 2  1373513885523551         B.Tech     Madrid      Spain  Temporary
# 3   401560922349533            PhD  New Delhi      India  Full-Time
# 4  2853459439973158         B.Tech     London         UK     Intern
#
#    Company Size Gender Preference            Job Title  \
# 0         23196              Male      Software Tester
# 1         27725              Both  Electrical Designer
# 2         91636              Male     Data Entry Clerk
# 3         42159            Female    Account Executive
# 4         58034              Male        Data Engineer
#
#               Specialization       Job Portal  ... Flexible Work Arrangements  \
# 0  Quality Assurance Analyst         Snagajob  ...                      False
# 1          Lighting Designer         Idealist  ...                      False
# 2              Record Keeper     Jobs2Careers  ...                      False
# 3    Sales Account Executive  Internships.com  ...                      False
# 4             Data Architect           Indeed  ...                       True
#
#   Health Insurance Life and Disability Insurance  Employee Assistance Program  \
# 0             True                          True                        False
# 1             True                          True                        False
# 2            False                         False                        False
# 3            False                         False                        False
# 4            False                         False                        False
#
#    Health and Wellness Facilities  Employee Referral Program  \
# 0                           False                      False
# 1                           False                      False
# 2                           False                      False
# 3                           False                      False
# 4                           False                      False
#
#    Transportation Benefits  Bonuses and Incentive Programs  \
# 0                    False                           False
# 1                    False                           False
# 2                    False                            True
# 3                    False                           False
# 4                    False                           False
#
#    Job City Population  Company HQ Country
# 0              1222657               India
# 1               472000                 USA
# 2              6751000                 USA
# 3             32941000                  UK
# 4              9748000                 USA
#
# [5 rows x 38 columns]

# %%
print(df.dtypes)
# Out:
# Job Id                             int64
# Qualifications                    object
# City                              object
# Country                           object
# Work Type                         object
# Company Size                       int64
# Gender Preference                 object
# Job Title                         object
# Specialization                    object
# Job Portal                        object
# Skills                            object
# Responsibilities                  object
# Company                           object
# Day                                int64
# Month                              int64
# Year                               int64
# Minimum Salary                     int64
# Maximum Salary                     int64
# Minimum Experience (years)         int64
# Maximum Experience (years)         int64
# Company Sector                    object
# Company Industry                  object
# Company HQ City                   object
# Company Ticker                    object
# Retirement Plans                    bool
# Stock Options or Equity Grants      bool
# Parental Leave                      bool
# Paid Time Off (PTO)                 bool
# Flexible Work Arrangements          bool
# Health Insurance                    bool
# Life and Disability Insurance       bool
# Employee Assistance Program         bool
# Health and Wellness Facilities      bool
# Employee Referral Program           bool
# Transportation Benefits             bool
# Bonuses and Incentive Programs      bool
# Job City Population                int64
# Company HQ Country                object
# dtype: object

# %% [markdown]
# Reorder Columns

# %%
# Reorder columns based on the desired order
desired_order = ['Job Id','Minimum Experience (years)',
                 'Maximum Experience (years)','Qualifications',
                 'Minimum Salary', 'Maximum Salary', 'City', 'Country', 'Job City Population',
                 'Work Type', 'Day', 'Month', 'Year', 'Gender Preference', 'Job Title', 'Specialization',
                 'Job Portal', 'Skills', 'Responsibilities', 'Company', 'Company Size', 'Company Sector',
                 'Company Industry', 'Company HQ City', 'Company HQ Country', 'Company Ticker',
                 'Retirement Plans', 'Stock Options or Equity Grants', 'Parental Leave','Paid Time Off (PTO)',
                 'Flexible Work Arrangements','Health Insurance', 'Life and Disability Insurance',
                 'Employee Assistance Program','Health and Wellness Facilities','Employee Referral Program',
                 'Transportation Benefits','Bonuses and Incentive Programs']

df = df[desired_order]
df.head(5)
# Out:
#              Job Id  Minimum Experience (years)  Maximum Experience (years)  \
# 0   116831420231957                           4                          12
# 1  1889088294438825                           0                           8
# 2  1373513885523551                           3                           9
# 3   401560922349533                           5                          12
# 4  2853459439973158                           0                           9
#
#   Qualifications  Minimum Salary  Maximum Salary       City    Country  \
# 0            MCA           59000           93000   Brussels    Belgium
# 1          M.Com           62000          130000   Canberra  Australia
# 2         B.Tech           56000          109000     Madrid      Spain
# 3            PhD           57000          125000  New Delhi      India
# 4         B.Tech           56000          125000     London         UK
#
#    Job City Population  Work Type  ...  Parental Leave  Paid Time Off (PTO)  \
# 0              1222657  Full-Time  ...           False                False
# 1               472000  Temporary  ...           False                False
# 2              6751000  Temporary  ...           False                False
# 3             32941000  Full-Time  ...           False                False
# 4              9748000     Intern  ...           False                 True
#
#    Flexible Work Arrangements Health Insurance Life and Disability Insurance  \
# 0                       False             True                          True
# 1                       False             True                          True
# 2                       False            False                         False
# 3                       False            False                         False
# 4                        True            False                         False
#
#   Employee Assistance Program Health and Wellness Facilities  \
# 0                       False                          False
# 1                       False                          False
# 2                       False                          False
# 3                       False                          False
# 4                       False                          False
#
#   Employee Referral Program Transportation Benefits  \
# 0                     False                   False
# 1                     False                   False
# 2                     False                   False
# 3                     False                   False
# 4                     False                   False
#
#   Bonuses and Incentive Programs
# 0                          False
# 1                          False
# 2                           True
# 3                          False
# 4                          False
#
# [5 rows x 38 columns]

# %% [markdown]
# ## Load

# %% [markdown]
# ### Surrogate Key Generation

# %%
# Create a new column new_result with sequential indices for each row
df['Surrogate Keys'] = range(1,len(df)+1)

# %%
# after generation, surrogate key column is at the end of the dataset
# this code brings it to the beginning
df = df.reindex(columns=['Surrogate Keys'] + list([c for c in df.columns if c!= 'Surrogate Keys']))

# %%
df.head(5)
# Out:
#    Surrogate Keys            Job Id  Minimum Experience (years)  \
# 0               1   116831420231957                           4
# 1               2  1889088294438825                           0
# 2               3  1373513885523551                           3
# 3               4   401560922349533                           5
# 4               5  2853459439973158                           0
#
#    Maximum Experience (years) Qualifications  Minimum Salary  Maximum Salary  \
# 0                          12            MCA           59000           93000
# 1                           8          M.Com           62000          130000
# 2                           9         B.Tech           56000          109000
# 3                          12            PhD           57000          125000
# 4                           9         B.Tech           56000          125000
#
#         City    Country  Job City Population  ... Parental Leave  \
# 0   Brussels    Belgium              1222657  ...          False
# 1   Canberra  Australia               472000  ...          False
# 2     Madrid      Spain              6751000  ...          False
# 3  New Delhi      India             32941000  ...          False
# 4     London         UK              9748000  ...          False
#
#    Paid Time Off (PTO)  Flexible Work Arrangements  Health Insurance  \
# 0                False                       False              True
# 1                False                       False              True
# 2                False                       False             False
# 3                False                       False             False
# 4                 True                        True             False
#
#   Life and Disability Insurance Employee Assistance Program  \
# 0                          True                       False
# 1                          True                       False
# 2                         False                       False
# 3                         False                       False
# 4                         False                       False
#
#   Health and Wellness Facilities Employee Referral Program  \
# 0                          False                     False
# 1                          False                     False
# 2                          False                     False
# 3                          False                     False
# 4                          False                     False
#
#   Transportation Benefits Bonuses and Incentive Programs
# 0                   False                          False
# 1                   False                          False
# 2                   False                           True
# 3                   False                          False
# 4                   False                          False
#
# [5 rows x 39 columns]

# %% [markdown]
# ### Saving the fully stagged data for loading into a csv

# %%
 # convert it back to csv
df.to_csv('Stagged_data.csv')
